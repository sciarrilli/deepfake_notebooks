# %%
import json
import pandas as pd
import os

# %%
dir = '/home/ec2-user/.fastai/data/deepfake/'

# %%
dirlist = os.listdir(dir)

# %%
metalist = []

for d in dirlist:
    metalist.append(os.path.join(dir, d))

# %%
templist = []

for i in metalist:
    templist.append(os.path.join(i, 'metadata.json'))

# %%
metalist = templist

# %%
len(metalist)
# Out:
# 50

# %%
sorted(metalist)
# Out:
# ['/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_00/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_01/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_02/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_03/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_04/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_05/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_06/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_07/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_08/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_09/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_10/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_11/metadata.json',
#  '/home/ec2-user/.fastai/data/deepfake/dfdc_train_part_12/metadata.json',
# ...

# %%
for json in metalist:
    os.listdir()

# %%
df0 = pd.read_json(metalist[0]).T
df1 = pd.read_json(metalist[1]).T
df2 = pd.read_json(metalist[2]).T
df3 = pd.read_json(metalist[3]).T
df4 = pd.read_json(metalist[4]).T
df5 = pd.read_json(metalist[5]).T
df6 = pd.read_json(metalist[6]).T
df7 = pd.read_json(metalist[7]).T
df8 = pd.read_json(metalist[8]).T
df9 = pd.read_json(metalist[9]).T
df10 = pd.read_json(metalist[10]).T
df11 = pd.read_json(metalist[11]).T
df12 = pd.read_json(metalist[12]).T
df13 = pd.read_json(metalist[13]).T
df14 = pd.read_json(metalist[14]).T
df15 = pd.read_json(metalist[15]).T
df16 = pd.read_json(metalist[16]).T
df17 = pd.read_json(metalist[17]).T
df18 = pd.read_json(metalist[18]).T
df19 = pd.read_json(metalist[19]).T
df20 = pd.read_json(metalist[20]).T
df21 = pd.read_json(metalist[21]).T
df22 = pd.read_json(metalist[22]).T
df23 = pd.read_json(metalist[23]).T
df24 = pd.read_json(metalist[24]).T
df25 = pd.read_json(metalist[25]).T
df26 = pd.read_json(metalist[26]).T
df27 = pd.read_json(metalist[27]).T
df28 = pd.read_json(metalist[28]).T
df29 = pd.read_json(metalist[29]).T
df30 = pd.read_json(metalist[30]).T
df31 = pd.read_json(metalist[31]).T
df32 = pd.read_json(metalist[32]).T
df33 = pd.read_json(metalist[33]).T
df34 = pd.read_json(metalist[34]).T
df35 = pd.read_json(metalist[35]).T
df36 = pd.read_json(metalist[36]).T
df37 = pd.read_json(metalist[37]).T
df38 = pd.read_json(metalist[38]).T
df39 = pd.read_json(metalist[39]).T
df40 = pd.read_json(metalist[40]).T
df41 = pd.read_json(metalist[41]).T
df42 = pd.read_json(metalist[42]).T
df43 = pd.read_json(metalist[43]).T
df44 = pd.read_json(metalist[44]).T
df45 = pd.read_json(metalist[45]).T
df46 = pd.read_json(metalist[46]).T
df47 = pd.read_json(metalist[47]).T
df48 = pd.read_json(metalist[48]).T
df49 = pd.read_json(metalist[49]).T

# %%
frames = [df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10,
          df11, df12, df13, df14, df15, df16, df17, df18, df19, df20,
          df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, 
          df31, df32, df33, df34, df35, df36, df37, df38, df39, df40, 
          df41, df42, df43, df44, df45, df46, df47, df48, df49
         ]

# %%
metadata = pd.concat(frames, axis=0, sort=False)

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119154 entries, dvglijlzdi.mp4 to gdhlrzpxxr.mp4
# Data columns (total 3 columns):
# label       119154 non-null object
# original    100000 non-null object
# split       119154 non-null object
# dtypes: object(3)
# memory usage: 3.6+ MB

# %%
metadata.head()
# Out:
#                label        original  split
# dvglijlzdi.mp4  FAKE  mwlwlieswy.mp4  train
# izwsybqjfz.mp4  FAKE  xqsivexncg.mp4  train
# yenswtjadf.mp4  FAKE  nekeugsope.mp4  train
# hzoccorwwg.mp4  FAKE  bqckuzlrar.mp4  train
# gmlomcyfap.mp4  FAKE  whneslhtcb.mp4  train

# %%
metadata.count()
# Out:
# label       119154
# original    100000
# split       119154
# dtype: int64

# %%
len(metadata)
# Out:
# 119154

# %%
metadata.describe
# Out:
# <bound method NDFrame.describe of                label        original  split
# dvglijlzdi.mp4  FAKE  mwlwlieswy.mp4  train
# izwsybqjfz.mp4  FAKE  xqsivexncg.mp4  train
# yenswtjadf.mp4  FAKE  nekeugsope.mp4  train
# hzoccorwwg.mp4  FAKE  bqckuzlrar.mp4  train
# gmlomcyfap.mp4  FAKE  whneslhtcb.mp4  train
# iybodcrcnc.mp4  FAKE  jutaplgsnv.mp4  train
# rrzgbpmwsb.mp4  FAKE  fpnhbgiuej.mp4  train
# xgxacqpvod.mp4  FAKE  actlcrgiug.mp4  train
# jfjudabiii.mp4  FAKE  gxtkpbexrm.mp4  train
# rsbmryngci.mp4  FAKE  gxtkpbexrm.mp4  train
# urnjvhmafb.mp4  FAKE  whneslhtcb.mp4  train
# qdvksyerxb.mp4  FAKE  ubyhbxawde.mp4  train
# vbikrjlxlb.mp4  FAKE  jjzzuodenm.mp4  train
# pigzvfybcf.mp4  FAKE  eigrxcetcn.mp4  train
# hamrpvfacp.mp4  FAKE  wxovupaocf.mp4  train
# mhriwvmxij.mp4  FAKE  hignttjkad.mp4  train
# htetkwbhxn.mp4  FAKE  uznzhtokgq.mp4  train
# jyjterhfex.mp4  FAKE  sojapnshoi.mp4  train
# vxgtlxsxlj.mp4  FAKE  ydvwivmlhk.mp4  train
# ssycivenqc.mp4  FAKE  ppvqtfbccs.mp4  train
# ...

# %%
metadata_df = metadata

# %%
len(metadata_df[metadata_df.label == "REAL"]), len(metadata_df[metadata_df.label == "FAKE"])
# Out:
# (19154, 100000)

# %%
metadata_df[metadata_df.index == "dvglijlzdi.mp4"]
# Out:
#                label        original  split
# dvglijlzdi.mp4  FAKE  mwlwlieswy.mp4  train

# %%
metadata_df.to_csv('/home/ec2-user/SageMaker/deepfake_notebooks/metadata_all.csv')

# %%
df49
# Out:
#                label        original  split
# hsypgwsufp.mp4  FAKE  nbnipejygk.mp4  train
# ntzgbkzofo.mp4  FAKE  cqlarprtdy.mp4  train
# ataulynpgd.mp4  FAKE  uzrkbzwdvi.mp4  train
# idzntwkkjy.mp4  FAKE  lvnjzrvzwy.mp4  train
# rdqokuannd.mp4  FAKE  mujubwlspn.mp4  train
# yezjulrvbi.mp4  FAKE  tdsfqvucbj.mp4  train
# peghucgqnp.mp4  FAKE  qqrqlucpeo.mp4  train
# zxebuyhswg.mp4  FAKE  qdscynormj.mp4  train
# wtomnouzjy.mp4  FAKE  gihwqgflcb.mp4  train
# isofcfjiar.mp4  FAKE  zgdtjzfrad.mp4  train
# ocpdyljoqx.mp4  FAKE  xosbvurwon.mp4  train
# ximaxvytgd.mp4  FAKE  znbriecxut.mp4  train
# kcoedzdmjj.mp4  FAKE  lvnjzrvzwy.mp4  train
# mparfojahr.mp4  FAKE  nbnipejygk.mp4  train
# jnkowcbdaf.mp4  FAKE  uzrkbzwdvi.mp4  train
# ewhdymgjmo.mp4  FAKE  pxtcygccjy.mp4  train
# ndrrlzsisg.mp4  FAKE  ozunaotrpe.mp4  train
# tkxvwexksu.mp4  FAKE  gcyecnxtht.mp4  train
# jvcvwiugzi.mp4  FAKE  wdpsifpppf.mp4  train
# nnjnjgfric.mp4  FAKE  tgmqpnqqwr.mp4  train
# ...
